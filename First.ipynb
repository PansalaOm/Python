# %% [markdown]
# <a href="https://colab.research.google.com/github/PansalaOm/Python/blob/main/First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Print Statment as OUTPUT

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Welocme to OM Pamnsala",7.2,2,True)
# Out:
# Welocme to OM Pamnsala 7.2 2 True

# %%
print("Om Pansala",21,sep = "/")
# Out:
# Om Pansala/21

# %% [markdown]
# #Data Types

# %%
#Integer
print(8)
# Out:
# 8

# %%
#doublee/Float
print(5.5)
# Out:
# 5.5

# %%
#String
print("Welcome to Code")
# Out:
# Welcome to Code

# %%
#BooleAN
print(True)
print(False)
# Out:
# True
# False

# %%
#Compleax
print(2+3j)
# Out:
# (2+3j)

# %%
#List -> arry
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#seat
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#Disneary
print({"Name":"Om","Age":21})
# Out:
# {'Name': 'Om', 'Age': 21}

# %% [markdown]
# #Variable

# %%
#Static vs Dyanamic Typeing
#Static vs Dyanamic Buindin
#New Declation Short

# %%
#Python Follow the Dyanamic Styping -> Not Declare the data type use the same variable to approches Multiple Data types

# %%
a = "Om Pansala"
print(a)
a= 21
print(a)
# Out:
# Om Pansala
# 21

# %%
a,b,c = 1,2,4
print(a,b,c)
# Out:
# 1 2 4

# %%
a=b=c = 23
print(a,b,c)
# Out:
# 23 23 23

# %% [markdown]
# #User Input

# %%
First_name= input("Enter Your Name")
Last_name= input("Enter Your Last Name")
print("Welcome",First_name,Last_name)
# Out:
# Enter Your NameOm
# Enter Your Last NamePatel
# Welcome Om Patel

# %% [markdown]
# #Type conversion

# %%
#Automatic
a = 21
b = 22.213
print(a+b)
# Out:
# 43.213

# %%
#Manually
a = int('23')
print(type(a))
print(a)
b = str(23)
print(b)
print(type(b))
# Out:
# <class 'int'>
# 23
# 23
# <class 'str'>
